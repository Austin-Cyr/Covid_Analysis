# %%
import pandas as pd

# %%
vax_by_cty_df = pd.read_csv("US_Vaccine_By_County.csv")

# %%
vax_by_cty_df.head()
# Out:
#          Date   FIPS  MMWR_week       Recip_County Recip_State  \
# 0  10/22/2021   6113         42        Yolo County          CA
# 1  10/22/2021  13221         42  Oglethorpe County          GA
# 2  10/22/2021  26097         42    Mackinac County          MI
# 3  10/22/2021  29015         42      Benton County          MO
# 4  10/22/2021  16021         42    Boundary County          ID
#
#    Series_Complete_Pop_Pct  Series_Complete_Yes  Series_Complete_12Plus  \
# 0                     60.3               132938                132558.0
# 1                     26.5                 4050                  4050.0
# 2                     69.5                 7505                  7504.0
# 3                     43.5                 8450                  8450.0
# 4                     29.2                 3580                     NaN
#
#    Series_Complete_12PlusPop_Pct  Series_Complete_18Plus  ...  SVI_CTGY  \
# 0                           69.5                  122484  ...         C
# ...

# %%
vax_by_cty_condensed = vax_by_cty_df.filter(["Date", "FIPS","Recip_County","Recip_State", "Series_Complete_Pop_Pct","Series_Complete_Yes","Metro_status"], axis=1)

# %%
vax_by_cty_condensed.head()
# Out:
#          Date   FIPS       Recip_County Recip_State  Series_Complete_Pop_Pct  \
# 0  10/22/2021   6113        Yolo County          CA                     60.3
# 1  10/22/2021  13221  Oglethorpe County          GA                     26.5
# 2  10/22/2021  26097    Mackinac County          MI                     69.5
# 3  10/22/2021  29015      Benton County          MO                     43.5
# 4  10/22/2021  16021    Boundary County          ID                     29.2
#
#    Series_Complete_Yes Metro_status
# 0               132938        Metro
# 1                 4050        Metro
# 2                 7505    Non-metro
# 3                 8450    Non-metro
# 4                 3580    Non-metro

# %%
vbc_df = vax_by_cty_condensed.dropna()

# %%
vbc_df
# Out:
#                Date   FIPS       Recip_County Recip_State  \
# 0        10/22/2021   6113        Yolo County          CA
# 1        10/22/2021  13221  Oglethorpe County          GA
# 2        10/22/2021  26097    Mackinac County          MI
# 3        10/22/2021  29015      Benton County          MO
# 4        10/22/2021  16021    Boundary County          ID
# ...             ...    ...                ...         ...
# 1030548  12/13/2020  13113     Fayette County          GA
# 1030549  12/13/2020  22017       Caddo Parish          LA
# 1030550  12/13/2020  21153    Magoffin County          KY
# 1030551  12/13/2020  19037   Chickasaw County          IA
# 1030552  12/13/2020  23017      Oxford County          ME
#
#          Series_Complete_Pop_Pct  Series_Complete_Yes Metro_status
# 0                           60.3               132938        Metro
# 1                           26.5                 4050        Metro
# ...
