# %%
import pandas as pd

# %%
cases_death_df = pd.read_csv("US_Cases_and_Deaths_by_State_over_Time.csv")

# %%
cases_death_df.head(50)
# Out:
#    submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0       02/12/2021    UT     359641    359641.0         0.0      1060
# 1       03/01/2021    CO     438745    411869.0     26876.0       677
# 2       08/22/2020    AR      56199         NaN         NaN       547
# 3       05/09/2021    PW          0         NaN         NaN         0
# 4       06/25/2021    MP        183       183.0         0.0         0
# 5       05/22/2021    MA     704796    659246.0     45550.0       451
# 6       07/29/2021    PR     146032    126814.0     19218.0       694
# 7       01/06/2021    TX    1867163         NaN         NaN     24010
# 8       07/26/2021    OK     475578    373929.0    101649.0      1028
# 9       11/25/2020    TX    1236648         NaN         NaN     18811
# 10      07/20/2020    GA     147804    143697.0      4107.0      2766
# 11      06/20/2021    PW          2         NaN         NaN         0
# ...
