# %%
import pandas as pd

# %%
complete_df = pd.read_csv("COVID-19_Case_Surveillance_Public_Use_Data.csv")

# %%
complete_df.head()
# Out:
#   cdc_case_earliest_dt  cdc_report_dt pos_spec_dt    onset_dt  \
# 0            2021/08/19    2021/08/19         NaN         NaN
# 1            2020/08/31    2021/05/06         NaN  2020/08/31
# 2            2020/12/27    2021/01/16         NaN  2020/12/27
# 3            2021/09/13    2021/09/13         NaN         NaN
# 4            2020/08/25    2020/08/28         NaN  2020/08/25
#
#               current_status   sex      age_group race_ethnicity_combined  \
# 0              Probable Case  Male  10 - 19 Years     Black, Non-Hispanic
# 1              Probable Case  Male  10 - 19 Years     Black, Non-Hispanic
# 2              Probable Case  Male  10 - 19 Years     Black, Non-Hispanic
# 3  Laboratory-confirmed case  Male  10 - 19 Years     Black, Non-Hispanic
# 4  Laboratory-confirmed case  Male  10 - 19 Years     Black, Non-Hispanic
#
#    hosp_yn   icu_yn death_yn medcond_yn
# 0  Missing  Missing  Missing    Missing
# 1  Missing  Missing  Missing    Missing
# ...
