# %%
import pandas as pd
import numpy as np

# %%
death_by_county_df = pd.read_csv("Provisional_COVID-19_Deaths_by_County__and_Race_and_Hispanic_Origin.csv")

# %%
death_by_county_df.head()
# Out:
#    Data as of  Start Date    End Date State             County Name  \
# 0  10/20/2021  01/01/2020  10/16/2021    AK  Anchorage Municipality
# 1  10/20/2021  01/01/2020  10/16/2021    AK  Anchorage Municipality
# 2  10/20/2021  01/01/2020  10/16/2021    AK  Anchorage Municipality
# 3  10/20/2021  01/01/2020  10/16/2021    AL          Autauga County
# 4  10/20/2021  01/01/2020  10/16/2021    AL          Autauga County
#
#    Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                 3           2           20       2020
# 1                 3           2           20       2020
# 2                 3           2           20       2020
# 3                 3           1            1       1001
# 4                 3           1            1       1001
#
#                               Indicator  ...  COVID-19 Deaths  \
# 0  Distribution of all-cause deaths (%)  ...              366
# 1   Distribution of COVID-19 deaths (%)  ...              366
# 2        Distribution of population (%)  ...              366
# 3  Distribution of all-cause deaths (%)  ...              122
# 4   Distribution of COVID-19 deaths (%)  ...              122
#
#    Non-Hispanic White  Non-Hispanic Black  \
# 0               0.578               0.043
# 1               0.413               0.027
# 2               0.564               0.052
# 3               0.823               0.166
# 4               0.721               0.246
#
#    Non-Hispanic American Indian or Alaska Native  Non-Hispanic Asian  \
# 0                                          0.207               0.061
# 1                                          0.265               0.150
# 2                                          0.083               0.098
# 3                                            NaN                 NaN
# 4                                            NaN                 NaN
#
#    Non-Hispanic Native Hawaiian or Other Pacific Islander  Hispanic  Other  \
# 0                                              0.030          0.032  0.051
# 1                                              0.079          0.033  0.033
# 2                                              0.031          0.095  0.077
# 3                                                NaN            NaN    NaN
# 4                                                NaN            NaN    NaN
#
#    Urban Rural Description                                           Footnote
# 0             Medium metro                                                NaN
# 1             Medium metro                                                NaN
# 2             Medium metro                                                NaN
# 3             Medium metro  One or more data cells have counts between 1-9...
# 4             Medium metro  One or more data cells have counts between 1-9...
#
# [5 rows x 21 columns]

# %%
death_by_county_condensed = death_by_county_df.filter(["Data as of", "State","County Name","Urban Rural Code", "FIPS State","FIPS Count","FIPS Code", "Indicator", "Total deaths", "COVID-19 Deaths", "Urban Rural Description",], axis=1)

# %%
death_by_county_condensed.head()
# Out:
#    Data as of State             County Name  Urban Rural Code  FIPS State  \
# 0  10/20/2021    AK  Anchorage Municipality                 3           2
# 1  10/20/2021    AK  Anchorage Municipality                 3           2
# 2  10/20/2021    AK  Anchorage Municipality                 3           2
# 3  10/20/2021    AL          Autauga County                 3           1
# 4  10/20/2021    AL          Autauga County                 3           1
#
#    FIPS Code                             Indicator  Total deaths  \
# 0       2020  Distribution of all-cause deaths (%)          4133
# 1       2020   Distribution of COVID-19 deaths (%)          4133
# 2       2020        Distribution of population (%)          4133
# 3       1001  Distribution of all-cause deaths (%)           956
# 4       1001   Distribution of COVID-19 deaths (%)           956
#
#    COVID-19 Deaths Urban Rural Description
# 0              366            Medium metro
# 1              366            Medium metro
# 2              366            Medium metro
# 3              122            Medium metro
# 4              122            Medium metro

# %%
death_by_county_condensed["Pct_Deaths_by_Covid"] = death_by_county_condensed["COVID-19 Deaths"] / death_by_county_condensed["Total deaths"] * 100

# %%
death_by_county_condensed
# Out:
#       Data as of State             County Name  Urban Rural Code  FIPS State  \
# 0     10/20/2021    AK  Anchorage Municipality                 3           2
# 1     10/20/2021    AK  Anchorage Municipality                 3           2
# 2     10/20/2021    AK  Anchorage Municipality                 3           2
# 3     10/20/2021    AL          Autauga County                 3           1
# 4     10/20/2021    AL          Autauga County                 3           1
# ...          ...   ...                     ...               ...         ...
# 2752  10/20/2021    WY          Laramie County                 4          56
# 2753  10/20/2021    WY          Laramie County                 4          56
# 2754  10/20/2021    WY          Natrona County                 4          56
# 2755  10/20/2021    WY          Natrona County                 4          56
# 2756  10/20/2021    WY          Natrona County                 4          56
#
#       FIPS Code                             Indicator  Total deaths  \
# 0          2020  Distribution of all-cause deaths (%)          4133
# 1          2020   Distribution of COVID-19 deaths (%)          4133
# 2          2020        Distribution of population (%)          4133
# 3          1001  Distribution of all-cause deaths (%)           956
# 4          1001   Distribution of COVID-19 deaths (%)           956
# ...         ...                                   ...           ...
# 2752      56021   Distribution of COVID-19 deaths (%)          1868
# 2753      56021        Distribution of population (%)          1868
# 2754      56025  Distribution of all-cause deaths (%)          1886
# 2755      56025   Distribution of COVID-19 deaths (%)          1886
# 2756      56025        Distribution of population (%)          1886
#
#       COVID-19 Deaths Urban Rural Description  Pct_Deaths_by_Covid
# 0                 366            Medium metro             8.855553
# 1                 366            Medium metro             8.855553
# 2                 366            Medium metro             8.855553
# 3                 122            Medium metro            12.761506
# 4                 122            Medium metro            12.761506
# ...               ...                     ...                  ...
# 2752              202             Small metro            10.813704
# 2753              202             Small metro            10.813704
# 2754              250             Small metro            13.255567
# 2755              250             Small metro            13.255567
# 2756              250             Small metro            13.255567
#
# [2757 rows x 11 columns]

# %%
death_by_county_condensed["Pct_Deaths_by_Covid"].describe()
# Out:
# count    2757.000000
# mean       12.464765
# std         3.818975
# min         3.585657
# 25%         9.935603
# 50%        12.069971
# 75%        14.583333
# max        26.998962
# Name: Pct_Deaths_by_Covid, dtype: float64

# %%
death_by_county_condensed["Pct_Deaths_by_Covid"].median()
# Out:
# 12.06997084548105

# %%
def create(row):
  if row['Pct_Deaths_by_Covid'] > 12.07:
    return 1
  else:
    return 0
death_by_county_condensed["Covid_Death_Pct_Above_Median"] = death_by_county_condensed.apply(create, axis=1)

# %%
death_by_county_condensed
# Out:
#       Data as of State             County Name  Urban Rural Code  FIPS State  \
# 0     10/20/2021    AK  Anchorage Municipality                 3           2
# 1     10/20/2021    AK  Anchorage Municipality                 3           2
# 2     10/20/2021    AK  Anchorage Municipality                 3           2
# 3     10/20/2021    AL          Autauga County                 3           1
# 4     10/20/2021    AL          Autauga County                 3           1
# ...          ...   ...                     ...               ...         ...
# 2752  10/20/2021    WY          Laramie County                 4          56
# 2753  10/20/2021    WY          Laramie County                 4          56
# 2754  10/20/2021    WY          Natrona County                 4          56
# 2755  10/20/2021    WY          Natrona County                 4          56
# 2756  10/20/2021    WY          Natrona County                 4          56
#
#       FIPS Code                             Indicator  Total deaths  \
# 0          2020  Distribution of all-cause deaths (%)          4133
# 1          2020   Distribution of COVID-19 deaths (%)          4133
# 2          2020        Distribution of population (%)          4133
# 3          1001  Distribution of all-cause deaths (%)           956
# 4          1001   Distribution of COVID-19 deaths (%)           956
# ...         ...                                   ...           ...
# 2752      56021   Distribution of COVID-19 deaths (%)          1868
# 2753      56021        Distribution of population (%)          1868
# 2754      56025  Distribution of all-cause deaths (%)          1886
# 2755      56025   Distribution of COVID-19 deaths (%)          1886
# 2756      56025        Distribution of population (%)          1886
#
#       COVID-19 Deaths Urban Rural Description  Pct_Deaths_by_Covid  \
# 0                 366            Medium metro             8.855553
# 1                 366            Medium metro             8.855553
# 2                 366            Medium metro             8.855553
# 3                 122            Medium metro            12.761506
# 4                 122            Medium metro            12.761506
# ...               ...                     ...                  ...
# 2752              202             Small metro            10.813704
# 2753              202             Small metro            10.813704
# 2754              250             Small metro            13.255567
# 2755              250             Small metro            13.255567
# 2756              250             Small metro            13.255567
#
#       Covid_Death_Pct_Above_Median
# 0                                0
# 1                                0
# 2                                0
# 3                                1
# 4                                1
# ...                            ...
# 2752                             0
# 2753                             0
# 2754                             1
# 2755                             1
# 2756                             1
#
# [2757 rows x 12 columns]
