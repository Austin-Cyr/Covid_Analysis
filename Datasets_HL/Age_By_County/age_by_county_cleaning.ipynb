# %%
import pandas as pd

# %%
age_by_county = pd.read_csv("../age_by_county/age_county_census.csv")
age_by_county.head(30)
# Out:
#     SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0       50      1       1  Alabama  Autauga County     1       0    54571
# 1       50      1       1  Alabama  Autauga County     1       1     3579
# 2       50      1       1  Alabama  Autauga County     1       2     3991
# 3       50      1       1  Alabama  Autauga County     1       3     4290
# 4       50      1       1  Alabama  Autauga County     1       4     4290
# 5       50      1       1  Alabama  Autauga County     1       5     3080
# 6       50      1       1  Alabama  Autauga County     1       6     3157
# 7       50      1       1  Alabama  Autauga County     1       7     3330
# 8       50      1       1  Alabama  Autauga County     1       8     4157
# 9       50      1       1  Alabama  Autauga County     1       9     4086
# 10      50      1       1  Alabama  Autauga County     1      10     4332
# 11      50      1       1  Alabama  Autauga County     1      11     3873
# ...

# %%
#Get only the data from latest available census estimate
current_date = age_by_county['YEAR']== 12
age_by_county= age_by_county[current_date]
age_by_county.head()
# Out:
#      SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 209      50      1       1  Alabama  Autauga County    12       0    55869
# 210      50      1       1  Alabama  Autauga County    12       1     3277
# 211      50      1       1  Alabama  Autauga County    12       2     3465
# 212      50      1       1  Alabama  Autauga County    12       3     3851
# 213      50      1       1  Alabama  Autauga County    12       4     3659
#
#      TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  \
# 209     27092       28777  ...        778          687         89
# 210      1713        1564  ...         76           53         10
# 211      1787        1678  ...         83           59          2
# 212      1977        1874  ...         84           67         11
# 213      1854        1805  ...         55           68          7
#
#      HBAC_FEMALE  HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  \
# ...

# %%
age_by_county = age_by_county.filter(["SUMLEV", "STATE", "COUNTY", "STNAME", "CTYNAME", "AGEGRP", "TOT_POP"])
age_by_county
# Out:
#         SUMLEV  STATE  COUNTY   STNAME         CTYNAME  AGEGRP  TOT_POP
# 209         50      1       1  Alabama  Autauga County       0    55869
# 210         50      1       1  Alabama  Autauga County       1     3277
# 211         50      1       1  Alabama  Autauga County       2     3465
# 212         50      1       1  Alabama  Autauga County       3     3851
# 213         50      1       1  Alabama  Autauga County       4     3659
# ...        ...    ...     ...      ...             ...     ...      ...
# 716371      50     56      45  Wyoming   Weston County      14      499
# 716372      50     56      45  Wyoming   Weston County      15      352
# 716373      50     56      45  Wyoming   Weston County      16      229
# 716374      50     56      45  Wyoming   Weston County      17      198
# 716375      50     56      45  Wyoming   Weston County      18      200
#
# [59698 rows x 7 columns]
